# %% [markdown]
# ## 세션(Session)
# - Streamlit의 세션 : 사용자가 웹 브라우저를 연 시점부터 닫을 때 까지의 Streamlit과의 상호작용(세션이 여러개라면 각각은 독립적으로 동작함)
# - streamlit은 새로 동작(ex 위젯의 변화 감지 등)할 때 마다 새로고침되거나 이전 변수값들이 초기화 되는데, 초기화가 되지 않고 변수의 상태를 유지시킬 필요가 있을 때 세션을 활용함(즉, 세션을 사용하지 않으면 제대로 된 웹 기능을 유지할 수 없음)
# - ***session_state*** : 세션 상태를 관리하고 유지시키는 함수로 웹 브라우저를 열고 있는 동안 지속되는 저장공간 객체(딕셔너리와 유사함)
# - 폼이 다수의 값을 입력받아 한 번에 제출하기 위한 용도였다면, 세션은 브라우저를 열고 있는 내내 값이 초기화 되지 않게 해줄 수 있음.

# %%
# %%writefile module/myApp22.py

import streamlit as st
import numpy as np
import pandas as pd

'😍세션 사용법😍'
''

# st.write('세션에 아무 값도 없는 초기 상태:', st.session_state)

# session_stste 내에 값을 카운트할 수 있는 cnt 키 값을 만들고 value를 0으로 초기화
 # <조건문과 not in을 사용한 이유>
 # 조건문이 없다면 페이지(코드) 재실행마다 cnt가 0으로 초기화되어 이전 상태나 사용자의 상호작용을 무시하게 될 수 있어서 그런 부분을 방지하기 위함.
 # (세션을 사용하는 이유가 이전 입력값들을 유지시키기 위함인데 코드 재실행 시 다시 초기값으로 초기화되는 것을 막아야함)
if 'cnt' not in st.session_state :
    st.session_state['cnt'] = 0

# st.write('조건문이 실행된 이후 :', st.session_state)

# 버튼이 들어갈 컬럼 설정
col1, col2, col3, _ = st.columns([1,1,1,4])

# 증가, 감소, 초기화 버튼
 # 해당 버튼을 클릭하면 button함수를 설정할 때 지정한 key값이 세션의 key로, value가 True로 변경되어 업데이트 됨
if col1.button('1증가', key='첫번째 key') :
    st.session_state['cnt'] += 1

if col2.button('1감소', key='두번째 key') :
    st.session_state['cnt'] -= 1

if col3.button('초기화', key='세번째 key') :
    st.session_state['cnt'] = 0

st.write(f' cnt= {st.session_state['cnt']}')  # 출력시에도 sessioin_state를 하나의 딕셔너리로 보고 그 값에 접근하는 코드로 출력
''
'___'
''
# 버튼을 눌러 폼을 보는 경우에 아래처럼 코드를 작성하면 제출하기 버튼을 누를 때 폼이 사라짐
# 즉, 제출 버튼을 누를 때 웹 통신이 발생하면서 기존 변수 값들이 초기화되고 유지되지 않게 
# if st.button('폼 보이기', key=5) :
#     with st.form(key='form1', clear_on_submit = False) :
#         name = st.text_input("What's your name?")
#         age = st.slider("How old are you?", 20, 40, 30)
#         gender = st.radio("What is your gender?", ['남','여'])
    
#         submit_button = st.form_submit_button('제출하기!')
    
#         if submit_button :
#             st.write(f"제출결과 >> '이름':{name}, '나이':{age}, '성별':{gender}")

# 폼과 버튼을 같이 활용하기 위해 세션을 사용하는 사용자 정의 함수 설정
# True, False와 같은 논리값들을 세션으로 유지시켜줌으로써 버튼과 폼을 함께 사용하게 구성할 수 있다.
def doClicked() :
    # get : 파이썬 기초의 get을 본따 만든 함수로 session_state에서 key값을 검색하는 함수(key명칭, 해당 key가 없을 때 반환되는 값)
    return st.session_state.get('clicked', False)

# doClicked 함수의 반환값이 True라면
# (처음에는 sessiion에 clicked 키 값이 없어서 False가 반환되므로 if문 대신 else문이 실행됨)
if doClicked() :
     with st.form(key='form1', clear_on_submit = False) :
            name = st.text_input("What's your name?")
            age = st.slider("How old are you?", 20, 40, 30)
            gender = st.radio("What is your gender?", ['남','여'])
        
            submit_button = st.form_submit_button('제출하기!')
        
            if submit_button :
                st.write(f"제출결과 >> '이름':{name}, '나이':{age}, '성별':{gender}")
# doClicked 함수의 반환값이 False라면
else :
    # 폼 보이기 버튼을 누르면 if문이 동작함
    if st.button('폼 보이기') :
        st.session_state['clicked'] = True    # sessin에 clicked가 없다가 True로 저장됨
        # rerun : 어플리케이션 재실행 (웹 브라우저를 끈 것이 아니므로 세션 상태는 유지됨)
        st.rerun()
# Out:
# Overwriting module/myApp22.py
