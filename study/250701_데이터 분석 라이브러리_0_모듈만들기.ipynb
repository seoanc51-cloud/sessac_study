# %%
# 모듈로 만들 코드
def myMul(num1, num2) :
    return num1 * num2

# %%
#mymy 폴더에 있는 moduletest 모듈 파일을 불러와서 해당 코드 기능을 사용하겠다는 뜻!
from mymy import moduletest as mt

# %%
mt.myMul(5,1)
# Out:
# 5

# %%
# mymy 폴더에 있는 moduletest 모듈의 myCal 클래스를 임포트!
from mymy.moduletest import myCal

# %%
a = myCal(1,2)
a.mySub()
# Out:
# -1
